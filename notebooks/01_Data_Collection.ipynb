# %% [markdown]
# # 01 - Data Collection
#
# ## Purpose
#
# This notebook imports the raw Eurovision datasets into the project, performs
# basic validation, filters the competition years used in the study, and stores
# the cleaned raw datasets for use in subsequent notebooks.
#
# This notebook does not perform feature engineering or model preparation.

# %%
# Mount Google Drive

from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import project configuration

import sys

sys.path.append("/content/drive/MyDrive/Eurovision_Prediction")

from config import *

# %%
import pandas as pd
import shutil
from pathlib import Path

# %%
print(PROJECT_ROOT)
print(RAW_DATA)
print(PROCESSED_DATA)
# Out:
# /content/drive/MyDrive/Eurovision_Prediction
# /content/drive/MyDrive/Eurovision_Prediction/data/raw
# /content/drive/MyDrive/Eurovision_Prediction/data/processed

# %%
DATASETS = PROJECT_ROOT / "datasets"

contestants_path = DATASETS / "contestants.csv"
votes_path = DATASETS / "votes.csv"

# %%
contestants = pd.read_csv(contestants_path)
votes = pd.read_csv(votes_path)

print("Contestants:", contestants.shape)
print("Votes:", votes.shape)
# Out:
# Contestants: (2501, 21)
# Votes: (56562, 9)

# %%
display(contestants.head())

display(votes.head())
# Out:
#    year to_country_id   to_country               performer  \
# 0  1956            ch  Switzerland                 Refrain
# 1  1956            nl  Netherlands                 Holland
# 2  1956            ch  Switzerland               Lys Assia
# 3  1956            be      Belgium             Fud Leclerc
# 4  1956            de      Germany  Walter Andreas Schwarz
#
#                               song  place_contest  sf_num  running_final  \
# 0                        Lys Assia            1.0     NaN            9.0
# 1       De Vogels Van  Jetty Paerl            NaN     NaN            1.0
# 2               Das Alte Karussell            NaN     NaN            2.0
# 3  Messieurs Les Noyés De La Seine            NaN     NaN            3.0
# 4    Im Wartesaal Zum Großen Glück            NaN     NaN            4.0
#
#    running_sf  place_final  ...  place_sf  points_sf  points_tele_final  \
# 0         NaN          1.0  ...       NaN        NaN                NaN
# ...

# %%
contestants.info()

print()

votes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2501 entries, 0 to 2500
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year               2501 non-null   int64
#  1   to_country_id      2501 non-null   object
#  2   to_country         2501 non-null   object
#  3   performer          2501 non-null   object
#  4   song               2499 non-null   object
#  5   place_contest      1775 non-null   float64
#  6   sf_num             713 non-null    float64
#  7   running_final      1474 non-null   float64
#  8   running_sf         713 non-null    float64
#  9   place_final        1462 non-null   float64
#  10  points_final       1461 non-null   float64
#  11  place_sf           713 non-null    float64
#  12  points_sf          713 non-null    float64
#  13  points_tele_final  257 non-null    float64
#  14  points_jury_final  257 non-null    float64
# ...

# %%
print("Contestants")

display(contestants.isnull().sum())

print()

print("Votes")

display(votes.isnull().sum())
# Out:
# Contestants
# year                    0
# to_country_id           0
# to_country              0
# performer               0
# song                    2
# place_contest         726
# sf_num               1788
# running_final        1027
# running_sf           1788
# place_final          1039
# points_final         1040
# place_sf             1788
# points_sf            1788
# points_tele_final    2244
# points_jury_final    2244
# points_tele_sf       2259
# points_jury_sf       2259
# composers               0
# lyricists            1068
# lyrics                  0
# youtube_url             0
# dtype: int64
# Votes
# year                   0
# round                  0
# from_country_id        0
# to_country_id          0
# from_country           0
# to_country             0
# total_points           0
# tele_points        39613
# jury_points        39613
# dtype: int64

# %%
print("Contestants duplicates:",
      contestants.duplicated().sum())

print("Votes duplicates:",
      votes.duplicated().sum())
# Out:
# Contestants duplicates: 0
# Votes duplicates: 0

# %%
print(
    contestants["year"].min(),
    contestants["year"].max()
)

print(
    votes["year"].min(),
    votes["year"].max()
)
# Out:
# 1956 2026
# 1957 2026

# %%
contestants.groupby("year").size()
# Out:
# year
# 1956    13
# 1957    10
# 1958    10
# 1959    11
# 1960    13
#         ..
# 2022    75
# 2023    68
# 2024    68
# 2025    68
# 2026    65
# Length: 70, dtype: int64

# %%
contestants.to_csv(
    RAW_DATA / "contestants.csv",
    index=False
)

votes.to_csv(
    RAW_DATA / "votes.csv",
    index=False
)

print("Datasets copied into data/raw/")
# Out:
# Datasets copied into data/raw/
